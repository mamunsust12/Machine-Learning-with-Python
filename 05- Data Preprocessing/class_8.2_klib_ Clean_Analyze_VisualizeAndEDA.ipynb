# %% [markdown]
# # Clean, Analyze, Visualize And Perform EDA With Klib Library In No Time

# %% [markdown]
# Key features:
# - visualize missing data using the missingval_plot function
# - perform data cleaning using the data_cleaning function
# - visualize the data distribution plot using the dist_plot function
# - visualize the correlation plot using the corr_plot function
# - visualize categorical column values using the cat_plot function

# %% [markdown]
# https://github.com/akanz1/klib/tree/main/examples

# %%
#!pip install klib

# %%
import klib

# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Correlation Plots
# This plot visualizes the correlation between different features. Settings include the possibility to only display positive, negative, high or low correlations as well as specify an additional threshold. This works for Person, Spearman and Kendall correlation. Annotations and development settings can optionally be turned on or off.

# %%
klib.corr_plot(df)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df, split='pos') # displaying only positive correlations, other settings include threshold, cmap...
klib.corr_plot(df, split='neg') # displaying only negative correlations
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %% [markdown]
# Further, as seen below, if a column is specified, either by name or by passing in a separate target List or pd.Series, the plot gives the correlation of all features with the specified target.

# %%
klib.corr_plot(df, target='survived') # default representation of correlations with the feature column
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.cat_plot(df, top=4, bottom=4) # representation of the 4 most & least common values in each categorical column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 klib.cat_plot(df, top=4, bottom=4)
#
# File C:\Anaconda\lib\site-packages\klib\describe.py:117, in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     114 data.loc[((data[col] != 10) & (data[col] != 0)), col] = 5
#     115 data[col] = data[col].rolling(2, min_periods=1).mean()
# --> 117 value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     118 value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     119 sum_top = sum(value_counts_top)
#
# File C:\Anaconda\lib\site-packages\klib\describe.py:117, in <listcomp>(.0)
#     114 data.loc[((data[col] != 10) & (data[col] != 0)), col] = 5
#     115 data[col] = data[col].rolling(2, min_periods=1).mean()
# --> 117 value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
# ...

# %%
klib.cat_plot(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 klib.cat_plot(df)
#
# File C:\Anaconda\lib\site-packages\klib\describe.py:117, in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     114 data.loc[((data[col] != 10) & (data[col] != 0)), col] = 5
#     115 data[col] = data[col].rolling(2, min_periods=1).mean()
# --> 117 value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     118 value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     119 sum_top = sum(value_counts_top)
#
# File C:\Anaconda\lib\site-packages\klib\describe.py:117, in <listcomp>(.0)
#     114 data.loc[((data[col] != 10) & (data[col] != 0)), col] = 5
#     115 data[col] = data[col].rolling(2, min_periods=1).mean()
# --> 117 value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
# ...

# %%
#klib.cat_plot(df)
#klib.corr_plot(df)
klib.dist_plot(df)
#klib.corr_mat(df)

#klib.missingval_plot(df)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
klib.corr_mat(df)
# Out:
# <style type="text/css">
# #T_26579_row0_col0, #T_26579_row0_col4, #T_26579_row0_col5, #T_26579_row1_col1, #T_26579_row1_col3, #T_26579_row1_col4, #T_26579_row1_col6, #T_26579_row1_col7, #T_26579_row2_col2, #T_26579_row2_col5, #T_26579_row2_col6, #T_26579_row2_col7, #T_26579_row3_col1, #T_26579_row3_col3, #T_26579_row3_col4, #T_26579_row3_col5, #T_26579_row4_col0, #T_26579_row4_col1, #T_26579_row4_col3, #T_26579_row4_col4, #T_26579_row4_col5, #T_26579_row5_col0, #T_26579_row5_col2, #T_26579_row5_col3, #T_26579_row5_col4, #T_26579_row5_col5, #T_26579_row6_col1, #T_26579_row6_col2, #T_26579_row6_col6, #T_26579_row6_col7, #T_26579_row7_col1, #T_26579_row7_col2, #T_26579_row7_col6, #T_26579_row7_col7 {
#   color: None;
# }
# ...

# %%
#klib.describe()

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %%
df_cleaned = klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (784, 15) - Remaining NAs: 692
#
#
# Dropped rows: 107
#      of which 107 duplicates. (Rows (first 150 shown): [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)

# %%
df_cleaned
# Out:
#      survived  pclass     sex   age  sibsp  parch       fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.250000        S  Third
# 1           1       1  female  38.0      1      0  71.283302        C  First
# 2           1       3  female  26.0      0      0   7.925000        S  Third
# 3           1       1  female  35.0      1      0  53.099998        S  First
# 4           0       3    male  35.0      0      0   8.050000        S  Third
# ..        ...     ...     ...   ...    ...    ...        ...      ...    ...
# 779         0       3  female  39.0      0      5  29.125000        Q  Third
# 780         1       1  female  19.0      0      0  30.000000        S  First
# 781         0       3  female   NaN      1      2  23.450001        S  Third
# 782         1       1    male  26.0      0      0  30.000000        C  First
# 783         0       3    male  32.0      0      0   7.750000        Q  Third
#
# ...

# %%
klib.cat_plot(df_cleaned)
# Out:
# GridSpec(6, 7)

# %%
klib.drop_missing(df)
klib.clean_column_names(df)
klib.mv_col_handling(df)
klib.drop_missing(df)

# %% [markdown]
# # Save Plot as a PDF file

# %%
plot = klib.corr_plot(df_cleaned, annot=False, figsize=(12,10))

# %%
plot.figure.savefig('figure.pdf')
