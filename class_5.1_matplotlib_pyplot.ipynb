# %% [markdown]
# # Visualization wit Matplotlib - Pyplot
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.5.1

# %%
import warnings
#warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# # Matplotlib Pyplot
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt
#from matplotlib import pyplot as ply

# %% [markdown]
# Now the Pyplot package can be referred to as plt.

# %% [markdown]
# # Plotting x and y points
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.

# %%
import matplotlib.pyplot as plt

x=[1,5,8]
y=[1,7,10]

plt.plot(x, y)

plt.show()

# %% [markdown]
# # Plotting Without Line
# To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 8])
ypoints = np.array([2, 8])

plt.plot(xpoints, ypoints, 'o') 
plt.grid()
plt.show()

# %%
#You can plot as many points as you like, just make sure you have the same number of points in both axis.

# %% [markdown]
# # ms = marker size, c=color,  mec =marker edge color, mfc =marker fill color

# %%
import matplotlib.pyplot as plt
import numpy as np

height=[1,2,3]
weight=[2,12,20]

#plt.plot(height, weight, '*')
plt.plot(x, y, '*' , ms = 20 , c='w', mec = 'r', mfc = 'r' ) # scatter plot with marker *

plt.title("Height Vs. Weight", loc = 'center') #left, right, center
plt.xlabel("Height")
plt.ylabel("weight")
plt.grid()
plt.show()

# %% [markdown]
# # Marker Properties

# %% [markdown]
# 1. argument : markersize or the shorter version, ms
#
#    plt.plot(ypoints, marker = 'o', ms = 20)
#
#
# 2. argument : markeredgecolor or the shorter mec
#
#    plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
#
#
# 3. argument : markerfacecolor or the shorter mfc to set the color inside the edge of the markers:
#
#    plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
#
# NB: Use both the mec and mfc arguments to color of the entire marker:
#
# plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
#
# plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
#
# plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
#
#
# 4. Line style : linestyle = 'dotted' or ls = ':' and linewidth = '20.5'
#
#     plt.plot(ypoints, linestyle = 'dotted')
#
#     'solid' (default)	'-'
#     'dotted'	':'
#     'dashed'	'--'
#     'dashdot'	'-.'
#     'None'	'' or ' '

# %% [markdown]
# # Label, Title, Font and Grid

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1, loc = 'center') #left, right, center
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid() # axis = 'y', axis='x'
plt.show()

# %% [markdown]
# # Scatter Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5])
y = np.array([5,10,15,15,20])
plt.scatter(x, y, color='hotpink')

plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5])
y = np.array([5,10,15,15,20])
plt.scatter(x, y, c='hotpink')

x = np.array([2,4,6,8,10])
y = np.array([5,7,10,12,18])
plt.scatter(x, y, color = '#88c999')

plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5])
y = np.array([10,20,30,40,50])

colors = np.array([0, 10, 20, 30, 40])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2,4,6,8,10])
y = np.array([5,10,15,20,25])
sizes = np.array([100,200,300,400,500])

plt.scatter(x, y, s=sizes, alpha=0.3)
plt.grid()
plt.show()

# %% [markdown]
# # Bar Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

gender=['Male','Female']
count=[10,6]

plt.bar(gender,count)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

# Horizontal bar chart
#plt.barh(x,y)
plt.bar(x,y, color = "hotpink", width = 0.5)

plt.show()

# %% [markdown]
# # Boxplot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 5,10,20,3,6,9,8,7,10,25,15,100]
plt.boxplot(x)
plt.show()

# %% [markdown]
# # Pie Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

x=[10,15,25]

plt.pie(x)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([35, 25, 25, 15])
l = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(x, labels = l)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(data, labels = mylabels, explode = myexplode)
plt.legend(title='Four Fruits')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors, autopct='%.0f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()
